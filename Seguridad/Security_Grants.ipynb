# %% [markdown]
# ### 1) Permisos de Catálogo y Esquemas

# %%
-- =========================
-- CATALOGO
-- =========================
GRANT USE CATALOG ON CATALOG `catalog_final_project` TO `DataEngineers`;
GRANT USE CATALOG ON CATALOG `catalog_final_project` TO `DataScientists`;

-- =========================
-- SCHEMAS - DataEngineers (ETL)
-- =========================
GRANT USE SCHEMA, CREATE, MODIFY, SELECT ON SCHEMA `catalog_final_project`.`bronze` TO `DataEngineers`;
GRANT USE SCHEMA, CREATE, MODIFY, SELECT ON SCHEMA `catalog_final_project`.`silver` TO `DataEngineers`;
GRANT USE SCHEMA, CREATE, MODIFY, SELECT ON SCHEMA `catalog_final_project`.`gold`   TO `DataEngineers`;

-- =========================
-- SCHEMAS - DataScientists (consumo / exploración)
-- =========================
GRANT USE SCHEMA, SELECT ON SCHEMA `catalog_final_project`.`silver` TO `DataScientists`;
GRANT USE SCHEMA, SELECT ON SCHEMA `catalog_final_project`.`gold`   TO `DataScientists`;

# %% [markdown]
# ### 2) Permisos sobre External Locations

# %%
-- =========================
-- EXTERNAL LOCATIONS - DataEngineers (read/write)
-- =========================
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw`    TO `DataEngineers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` TO `DataEngineers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` TO `DataEngineers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-gold`   TO `DataEngineers`;

-- =========================
-- EXTERNAL LOCATIONS - DataScientists (solo lectura)
-- =========================
GRANT READ FILES ON EXTERNAL LOCATION `exlt-silver` TO `DataScientists`;
GRANT READ FILES ON EXTERNAL LOCATION `exlt-gold`   TO `DataScientists`;

-- (Opcional) Si DataScientists necesita ver RAW:
-- GRANT READ FILES ON EXTERNAL LOCATION `exlt-raw` TO `DataScientists`;

# %% [markdown]
# ### 3) Permisos explícitos para tablas GOLD (para dashboard / consumo)

# %%
GRANT SELECT ON TABLE `catalog_final_project`.`gold`.`daily_kpis` TO `DataScientists`;
GRANT SELECT ON TABLE `catalog_final_project`.`gold`.`plant_performance_summary` TO `DataScientists`;

# %% [markdown]
# ### 4) Auditoría / Validación

# %%
-- =========================
-- VALIDACION CATALOGO Y SCHEMAS
-- =========================
SHOW GRANTS ON CATALOG `catalog_final_project`;
SHOW GRANTS ON SCHEMA `catalog_final_project`.`bronze`;
SHOW GRANTS ON SCHEMA `catalog_final_project`.`silver`;
SHOW GRANTS ON SCHEMA `catalog_final_project`.`gold`;

-- =========================
-- VALIDACION EXTERNAL LOCATIONS
-- =========================
SHOW GRANTS ON EXTERNAL LOCATION `exlt-raw`;
SHOW GRANTS ON EXTERNAL LOCATION `exlt-bronze`;
SHOW GRANTS ON EXTERNAL LOCATION `exlt-silver`;
SHOW GRANTS ON EXTERNAL LOCATION `exlt-gold`;
