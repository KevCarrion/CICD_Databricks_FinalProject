# %%
# Definición de variables (opcional pero recomendado)
CATALOG = "catalog_final_project"
GROUP_ENGINEERS = "DataEngineers"
GROUP_SCIENTISTS = "DataScientists"

# Ejecutar GRANTs
spark.sql(f"GRANT USE CATALOG ON CATALOG `{CATALOG}` TO `{GROUP_ENGINEERS}`")
spark.sql(f"GRANT USE CATALOG ON CATALOG `{CATALOG}` TO `{GROUP_SCIENTISTS}`")

print("Permisos USE CATALOG aplicados correctamente.")
